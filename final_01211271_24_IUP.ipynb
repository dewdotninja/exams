# %% [markdown]
# <p align="left">
# <img src="https://raw.githubusercontent.com/dewdotninja/exams/main/feng_heading_en.png" width=400 alt="Feng heading"/>
# </p>
#
# #### Final Exam, Second Semester, Academic Year 2024
# <br>01211271 Industrial AI and IoT
# <br>Thursday April 17, 2025 9:00 - 12:00
# <br>This exam is administered online via Google classroom only.
#
# Type student name - surname and ID in the cell below.

# %% [markdown]
# **Important :** Copy and paste this statement to the cell below. Failure to do so will result in score deduction.
#
# *I vow that I do this exam by myself without help from any person.*

# %% [markdown]
# ### Instructions
#
# 1. You can use Colab environment or install Jupyter notebook on your local machine.
# Type your work solely on this notebook. You can add as many cells as you want.
# Formatting is not necessary as long as your texts/equations are understandable and
# answer the question clearly.
# 2. Open books, notes and online resources. No help from any other person. Online social program such as line, facebook, X, etc. is strictly prohibited.
# 3. Explain clearly. Show details of your computation to receive full credits. For any problem
# that requires programming, your program should executer without error and give the correct
# result.
# * **Important :** Whenever help is provided in the form of incomplete code, you should always use that code and fill in the missing lines or function, instead of generating a new one by your own or using AI. If that code is hard to understand and, worse, does not work, you may get only some minimal or even zero score.
# 4. Do not change any problem. That will result in zero score for that problem.
# 5. Some parameters in the problem set may be a function of your student ID. You must make sure
# to substitute the right value for such parameters. Wrong substitution will result in significant score deduction.
# 6. Though not required, I allow additional file submission such as captured screen images if that can help clarify your work.
# 7. For Wokwi + NETPIE simulation, it is crucial that you copy from Wokwi complete C-code from sketch.ino and JSON code from diagram.json, and from NETPIE the dashboard.json code,because the grader will grade you from the code. If any of the code is incomplete, you would get minimal score close to zero.
# 8. <b>Important : </b>Students must submit your notebook promptly in Google classroom, as copy of Google drive file (link not acceptable),
# when the 3-hour exam period expires. Resubmission is acceptable only within the exam period. Late penalty is -1 score deduction per minute.
# <br><em>Anyone who submits/resubmits later than 10 minutes after the exam period, as indicated in the
# recorded history of Google classroom, may be considered cheating and may fail this exam.</em>

# %% [markdown]
# ***
# <div align="left">
# <b>Dean of Faculty of Engineering</b>  &emsp;      Head of Examination Committee
# <br><b>Mechanical Engieering Department Head</b>  &emsp;     Examination Committee
# <br><b>Dr. Varodom Toochinda</b>    &emsp;    Examination Committee
# </div>

# %% [markdown]
# #### Further explantion about exam problem that may depend on the last 3 digits of your student ID
#
# -------x_id,y_id,z_id (other digits are disregarded)
#
# #### Examples
#
# Student A's ID - 6010555853 results in x_id = 8, y_id = 5, z_id = 3
#
# Student B 's ID - 6010546104 results in x_id = 1, y_id = 0, z_id = 4
#
# Student C 's ID - 6310055032 results in x_id = 0, y_id = 3, z_id = 2
#
# These valuess are used for all the problems in the exam where x_id,y_id,and/or z_id appear. In this
# sense, the results from each student should be different even computed using the same methods.
#
# Operations that may be applied to the variables.
#
# $+$ addition
#
#  $-$  subtraction
#
#  $*$  multiplication
#
#  $/$ division
#
# $**$ raise to the power (For example, x_id**z_id means $x_{id}^{z_{id}}$)
#
# including math opertions such as $\exp(x_{id})$, $\sin(z_{id}*t)$
#
#
# Conditional statement may be used, such as
# if x_id<5 do task A, otherwise do task B
#
# <em>Example: </em> Let $R1 = 1000*(x_{id}+1) \,\Omega, C1 = 10*(y_{id}+2) \,\mu F$
#
# <ul>
# <li />Student A (x_id=8, y_id=5) does this problem with R1 = 9000 $\Omega$, C1 = 70 $\mu$F
# <li />Student B (x_id=1, y_id=0) does this problem with R1 = 2000 $\Omega$, C1 = 20 $\mu$F
# <li />Student C (x_id=0, y_id=3) does this problem with R1 = 1000 $\Omega$, C1 = 50 $\mu$F
# </ul>
#
# If any exam problem is not clear enough, write in a cell how you interpret it. If several
# students get confused on that problem, the grader may decide to give full credit to all.

# %% [markdown]
# ***
# ### List of exam problems (100 points)
#
# * [P1. (40 points)](#p1)
# * [P2. (30 points)](#p2)
# * [P3. (30 points)](#p3)

# %% [markdown]
# ***
# <a id="p1"></a>
# #### P1. (40 points)
#
# Create an ESP32 IoT device, using Micropython on Wokwi, to measure 3-D acceleration and 3-D rotation of a drone using mcu6050 sensor (available in Wokwi library). XYZ accelerations and XYZ rotations (total 6 values) are displayed by gauge widgets on NETPIE dashboard. Limits for acceleration and rotation values can be set by 2 sliders on dashboard. Whenever the absolute value of any quantity exceeds limit, an LED in the diagram as well as an indicator light on NETPIE dashboard must be turned on. Whenever the push-button switch or a button on NETPIE dashboard is pressed, your name-surname and student ID is displayed on a text widget on NETPIE dashboard.
#
# You should use this project as a start and fill in the incomplete code.
#
# https://wokwi.com/projects/428272207622756353
#
# **Note :** Though using AI to generate code is not prohibited, it is unlikely to fullfil all the requirements. If the code is wrong or meaningless, your score will decrease significantly.
#
# Detailed instructions for each task and corresponding score are listed below. Be sure to satisfy all of them to receive full credit.
#
# 1. (5 points) Create a correct ESP32 micropython Wokwi project. Circuit diagram must consist of mpu6050 sensor, an LED with current-limited resistor, and a push-button switch. The program should be able to run without error.
#
# 2. (15 points) All these basic functions must be fullfiled.
#
# * Read XYZ accelerations and rotations (total 6 values) from mpu6050 every 100 milliseconds
# * Whenever any absolute value of the 6 measurements exceeded its limit set from NETPIE, the LED must turn on. Otherwise, LED is off.
# * Special consideration is needed when applying limit for acceleration along Z axis. Normally, the gravity results in value of 1g for Z axis. So the acceleration limit on Z axis should be abs(acc_Z) - 1 \< acclim, where acclim is the value set by the slider.
# * Can connect to Wokwi wifi and NETPIE.
# * Write code to send data to NETPIE shadow and dashboard correctly every 1 second.
# * Whenver the push button is pushed, your name-surname and ID must be sent to NETPIE dashboard.
#
# 3. On NETPIE side (20 points)
#
# * (10 points) Notice that the values have different units on the sensor and readouts. On the sensor, acceleration unit is g, rotation unit is deg/sec. Readout values are in raw unit. You must convert those raw values to sensor values correctly. Then, write 6 raw values to NETPIE shadow to store them, and send converted value directly to NETPIE dashboard as comma-separated string, to display on 6 gauge widgets.
#
# * (10 points) Dashboard should contain
#     * 6 gauge widgets to display XYZ accleration (unit in g) and XYZ rotation (unit in deg/sec)
#     * 2 slider widgets, one for setting XYZ acceleration limit and one for XYZ rotation limit. Limit values must be in g and deg/sec for acceleration and rotation, respectively. Range of acceleration limit is 0.1 - 2 g, and range of rotation limit is 10 - 180 deg/s. Auto update value fields must be set to match the values on ESP32.
#     * 1 text widget to display your name-surname and ID whenever the push button switch on diagram or a button on dashboard is pressed.
#     * 1 button to command ESP32 to send name-surname and Id when it is pushed.
#     * 1 indicator light that is turned on when the absolute value for any of the 6 mpu6050 values exceeds its limit set by sliders.
#
# Some captured images of expected result.
# <table>
# <tr>
# <td><img src="https://raw.githubusercontent.com/dewdotninja/sharing-github/refs/heads/master/iaiiot/iaiiot24_iup_final_diagram.png"  />
#  </td>
# <td><img src="https://raw.githubusercontent.com/dewdotninja/sharing-github/refs/heads/master/iaiiot/iaiiot24_iup_final_shadow.png"  />
#  </td>
# <td><img src="https://raw.githubusercontent.com/dewdotninja/sharing-github/refs/heads/master/iaiiot/iaiiot24_iup_final_dashboard.png"  />
#  </td>
# </tr>
# </table>
#
# After you are certain that all the requirements are satisfied, prepare to copy your work to this notebook. It is your responsibility to make sure that the code in each cell below is completed. Your score depends on it.
#
# 1. copy all code from main.py in your Wokwi project to the cell below.

# %% [markdown]
# 2. Copy all code from diagram.json in your Wokwi project to the cell below.

# %% [markdown]
# **Note :** Your code will be tested using the given mpu6050.mpy. Do not use any other mpu6050
# library from elsewhere or the code may fail.
#
# 3. Export dashboard.json from NETPIE and copy all code to the cell below.

# %% [markdown]
# <hr>
#
# <a id="p2"></a>
# #### P2. (30 points)
#
# Create a simple 2 inputs neural network to learn the following function
# $$
# v = (y_{id})u_1 + (x_{id}-z_{id})u_2 - z_{id} \tag{P2.1}
# $$
#
#
# 1. (2 points) Write a function for (P2.1)

# %%
def f1(u1,u2):
    v = ?
    return v

# %% [markdown]
# 2. (5 points) Create data array inp1, inp2 and target for training, each has length 3000 points

# %%
# Hint : random arrays work well.
inp1 = ?
inp2 = ?

# %%
target = f1(inp1,inp2)

# %% [markdown]
# 3. (3 points) Create a neural network model with 2 inputs and 1 output using ternsorflow.

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, concatenate

# %%
x1 = Input(shape = (1,))
x2 = Input(shape = (1,))
input_layer = concatenate([?,?])
prediction = ?(?, activation='?')(input_layer)
model = Model(inputs=[?,?], outputs = prediction)

# %% [markdown]
# 4. Compile model with loss=mean-squared-error, optimizer=adam, and matrics=mae

# %%
model.compile(loss="mean_squared_error",
              optimizer='adam',
              metrics=['mae'])

# %% [markdown]
# 5. (5 points) Train the model for 300 epochs. Loss should decrease and accuracy should increase.

# %%
model.fit([? ?], ?, epochs=?,
          batch_size=32, verbose=2)
# Out:
# Epoch 1/300
# 94/94 - 1s - 9ms/step - loss: 33.5784 - mae: 5.3768
# Epoch 2/300
# 94/94 - 0s - 2ms/step - loss: 31.4561 - mae: 5.1907
# Epoch 3/300
# 94/94 - 0s - 4ms/step - loss: 29.4391 - mae: 5.0084
# Epoch 4/300
# 94/94 - 0s - 3ms/step - loss: 27.5243 - mae: 4.8292
# Epoch 5/300
# 94/94 - 0s - 3ms/step - loss: 25.7044 - mae: 4.6526
# Epoch 6/300
# 94/94 - 0s - 3ms/step - loss: 23.9809 - mae: 4.4791
# Epoch 7/300
# 94/94 - 0s - 3ms/step - loss: 22.3457 - mae: 4.3095
# Epoch 8/300
# 94/94 - 0s - 3ms/step - loss: 20.7989 - mae: 4.1427
# Epoch 9/300
# 94/94 - 0s - 3ms/step - loss: 19.3365 - mae: 3.9797
# Epoch 10/300
# 94/94 - 1s - 6ms/step - loss: 17.9539 - mae: 3.8206
# Epoch 11/300
# 94/94 - 0s - 2ms/step - loss: 16.6504 - mae: 3.6643
# Epoch 12/300
# 94/94 - 0s - 3ms/step - loss: 15.4199 - mae: 3.5134
# Epoch 13/300
# 94/94 - 0s - 2ms/step - loss: 14.2607 - mae: 3.3653
# Epoch 14/300
# 94/94 - 0s - 2ms/step - loss: 13.1719 - mae: 3.2196
# Epoch 15/300
# ...

# %% [markdown]
# 6. (5 points)Compare model prediction with target. The error should be small.

# %%
predict_out = model.predict([?,?])
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# compare result here
# Out:
# np.float64(0.009577414798438192)

# %% [markdown]
# 7. (5 points) Extract the model weights and compare with (P2.1); i.e., w1 = y_id, w2 = (x_id - z_id), b = -z_id

# %%
# get model weights

# %%
# from your student ID
print(y_id)
print(x_id-z_id)
print(-z_id)

# %% [markdown]
# 8. (5 points)  Suppose the function you want to learn is
# $$
# v = (y_{id})u_1sin(u_2) + (x_{id}-z_{id})u_2^2 - z_{id} \tag{P2.2}
# $$
#
# Write a function for (P2.2) and suggest how you would create a model to handle this nonlinear function. You don't need to actually build this model and train.

# %%
def f2(u1,u2):
    v = 
    return v

# %%
# Your suggestion on how to create a model for this function.

# %% [markdown]
# <hr>
#
# <a id="p3"></a>
# #### P3. (30 points)
#
# In this problem we will use neural network to classify cat or dog. This is example 4.2 in [chapter 4](https://github.com/dewdotninja/books/blob/main/anndl/notebooks/chapter4.ipynb) of my Thai book. Use the code from that example and modify as needed. Some are filled in for you.
#
# **Tips :** Use GPU on Colab to speed up the training.

# %% [markdown]
# Download the dataset using wget. You must have it installed on your computer.
# (In case you don't have wget, copy the link to your browser. The file cat_and_dogs_filtered.zip should then be downloaded to your computer. Then place it manually to the /tmp/ directory on your google drive.)

# %%
# !wget --no-check-certificate \
  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
  -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2025-04-14 09:10:00--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 192.178.163.207, 173.194.202.207, 173.194.203.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|192.178.163.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   164MB/s    in 0.4s
#
# 2025-04-14 09:10:01 (164 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %% [markdown]
# Call OS library to extract file to /tmp

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# files are extracted to /tmp/cats_and_dogs_filtered on your Google drive, separated to train and validation, and cats and dogs, to be conveniently used by ImageGenerator.

# %%
base_dir = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# Directory with our training cat/dog pictures
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# Directory with our validation cat/dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

print(train_cat_fnames[:10])
print(train_dog_fnames[:10])
# Out:
# ['cat.757.jpg', 'cat.599.jpg', 'cat.260.jpg', 'cat.846.jpg', 'cat.115.jpg', 'cat.366.jpg', 'cat.166.jpg', 'cat.629.jpg', 'cat.799.jpg', 'cat.344.jpg']
# ['dog.991.jpg', 'dog.365.jpg', 'dog.372.jpg', 'dog.745.jpg', 'dog.202.jpg', 'dog.755.jpg', 'dog.4.jpg', 'dog.753.jpg', 'dog.94.jpg', 'dog.212.jpg']

# %%
print('Numer of cat pictures for training :', len(os.listdir(      train_cats_dir ) ))
print('Numer of dog pictures for training :', len(os.listdir(      train_dogs_dir ) ))

print('Numer of cat pictures for validation :', len(os.listdir( validation_cats_dir ) ))
print('Numer of dog pictures for validation :', len(os.listdir( validation_dogs_dir ) ))
# Out:
# Numer of cat pictures for training : 1000
# Numer of dog pictures for training : 1000
# Numer of cat pictures for validation : 500
# Numer of dog pictures for validation : 500

# %% [markdown]
# Show some of the pictures.

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows = 4
ncols = 4
pic_index = 0

# %%
fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)
pic_index+=8
next_cat_pix = [os.path.join(train_cats_dir, fname)
                for fname in train_cat_fnames[ pic_index-8:pic_index]
               ]

next_dog_pix = [os.path.join(train_dogs_dir, fname)
                for fname in train_dog_fnames[ pic_index-8:pic_index]
               ]
for i, img_path in enumerate(next_cat_pix+next_dog_pix):
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off')
    img = mpimg.imread(img_path)
    plt.imshow(img)
plt.show()

# %% [markdown]
# Import all the required libraries.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import SGD, RMSprop, Adam

# %% [markdown]
# **Graded cell** (10 points)
#
# Create CNN model with layers conforming to this
# model summary. All convolution layers use (3,3) filter, stride=1, and 'relu' activation. All max pooling layers use pool size (2,2). Rate of dropout layer is 0.5.
#
# <img src="https://raw.githubusercontent.com/dewdotninja/sharing-github/refs/heads/master/iaiiot/iaiiot24_iup_final_cnn_model.png" width=600 />

# %%
model = Sequential([
    Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    # stack layers according to the table above
])

# %% [markdown]
# Verify that the output of this cell matches the picture above.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 32)     │         9,248 │
# ...

# %% [markdown]
# **Graded cell :** (5 points)
#
# Compile the model using adam optimizer with learning rate = 0.001, loss='binary_crossentropy', metrics = 'accuracy'

# %%
model.compile() # fill in arguments

# %% [markdown]
# Use ImageDataGenerator to categorize images for training, testing, and validation.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )
train_generator = train_datagen.flow_from_directory(train_dir,batch_size=20,class_mode='binary',target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,batch_size=20,class_mode  = 'binary',target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# Define learning-rate scheduler and early stopping. (No need to add/edit this cell.)

# %%
def scheduler(epoch, lr):
    return lr * (1/(1+epoch))
lr_scheduler = LearningRateScheduler(scheduler, verbose=1)
early_stopping = EarlyStopping(patience=3, monitor='val_accuracy', mode='max')

# %% [markdown]
# **Graded Cell :** (5 points)
#
# Train the model you created for 15 epochs, with the scheduler and early_stopping callbacks defined above.

# %% [markdown]
# **Note :** Traning could take long time. You should work on other problem in this exam while waiting for it to finish.

# %%
history = model.fit(train_generator,validation_data=validation_generator,steps_per_epoch=100,epochs=?,validation_steps=50,verbose=2,callbacks=[?,?])

# %% [markdown]
# (5 points) Answer this question. Does the training stop before reaching epoch 15? If it does, explain why.

# %% [markdown]
# Plot accuracy and loss.

# %%
def plot_acc_loss(history):
    acc=history.history['accuracy']
    val_acc=history.history['val_accuracy']
    loss=history.history['loss']
    val_loss=history.history['val_loss']
    epochs=range(len(acc)) # Get number of epochs
    acc_txt = str(round(acc[len(acc)-1]*100,2))
    val_acc_txt = str(round(val_acc[len(val_acc)-1]*100,2))
    fig, (ax1, ax2) = plt.subplots(1,2)
    ax1.plot(epochs, acc,'r',epochs,val_acc,'b')
    ax1.set_title('Training and validation accuracy')
    ax1.legend(["Training acc = "+acc_txt+" %","Validation acc = "+val_acc_txt+" %"])
    loss_txt = str(round(loss[len(loss)-1],2))
    val_loss_txt = str(round(val_loss[len(val_loss)-1],2))
    ax2.plot(epochs, loss, 'r',epochs, val_loss, 'b')
    ax2.legend(["Training loss = "+loss_txt,"Validation loss = "+val_loss_txt])
    ax2.set_title('Training and validation loss');

# %%
plot_acc_loss(history)

# %% [markdown]
# Expected accurary:
# * training $\approx$ 90%
# * validation $\approx$ 70%
#
# (5 points) Explain why training accuracy is greater than validation accuracy.

# %% [markdown]
# **Optional :** (no score)
#
# You may want to test if your trained model could classify a picture it has never seen before.
#
# If there is not enough time, you can test this anytime after the exam. Don't worry there is no grade on this part.
#
# **Important :** You can play around with this at home, but **do not** resubmit this notebook after the exam period expires!
#
# Find your own pet picture (or pick one from internet) and put it in the content folder. Change fn to that file name and test whether it is a cat or a dog.

# %%
import numpy as np
from keras.preprocessing import image
fn = "honey1.jpg"
# predicting images
path='/content/' + fn
img=image.load_img(path, target_size=(150, 150))
plt.imshow(img)
plt.axis('off')
x=image.img_to_array(img)
x=np.expand_dims(x, axis=0)
images = np.vstack([x])
classes = model.predict(images, batch_size=10)
if classes[0]>0:
    print(fn + " is a dog")
else:
    print(fn + " is a cat")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# honey1.jpg is a dog

# %% [markdown]
# <div align=right>Revision A : April 14, 2025</div>
